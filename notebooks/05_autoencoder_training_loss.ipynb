# %%
import matplotlib.pyplot as plt

# Loss values
loss_canola = [
0.0541,0.0535,0.0535,0.0535,0.0535,
0.0535,0.0535,0.0535,0.0535,0.0120,
0.0022,0.0016,0.0011,0.0010,0.0010,
0.0009,0.0009,0.0010,0.0009,0.0008
]

loss_soybean = [
0.0009,0.0008,0.0009,0.0007,0.0007,
0.0008,0.0009,0.0007,0.0007,0.0009,
0.0007,0.0007,0.0006,0.0007,0.0008,
0.0007,0.0008,0.0007,0.0007,0.0007
]

loss_waterhemp = [
0.0005,0.0005,0.0006,0.0006,0.0005,
0.0006,0.0006,0.0005,0.0005,0.0005,
0.0005,0.0005,0.0005,0.0005,0.0005,
0.0005,0.0006,0.0005,0.0005,0.0005
]

epochs = range(1, 21)

plt.figure(figsize=(7,5))

plt.plot(epochs, loss_canola, marker='o', label="Canola")
plt.plot(epochs, loss_soybean, marker='s', label="Soybean")
plt.plot(epochs, loss_waterhemp, marker='^', label="Waterhemp")

plt.xlabel("Epoch")
plt.ylabel("Reconstruction Loss")
plt.title("Autoencoder Training Loss for Different Crops")
plt.legend()

plt.grid(True)

plt.savefig("autoencoder_training_loss.png", dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt

loss_canola = [
0.0541,0.0535,0.0535,0.0535,0.0535,
0.0535,0.0535,0.0535,0.0535,0.0120,
0.0022,0.0016,0.0011,0.0010,0.0010,
0.0009,0.0009,0.0010,0.0009,0.0008
]

plt.plot(loss_canola, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Reconstruction Loss")
plt.title("Autoencoder Training Loss (Canola)")
plt.grid(True)
plt.show()
